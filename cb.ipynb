# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
file_path = 'key_rate.xlsx'

df = pd.read_excel(
    file_path,
    engine='openpyxl',
    names = ['Data', 'Key_rate', 'Inflation', 'Inflation_target']

    )
df['Data'] = df['Data'].astype(str)
df['Year'] = df['Data'].str[-4:]

df['Data'] = df['Data'].str.replace('.', '-')
# df['Data'] = pd.to_datetime(df['Data'], format='%m-%Y')
df
# Out:
# /Users/pyrowoon/Library/Python/3.12/lib/python/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#         Data  Key_rate  Inflation  Inflation_target  Year
# 0    12-2024      21.0       9.52               4.0  2024
# 1    11-2024      21.0       8.88               4.0  2024
# 2    10-2024      21.0       8.54               4.0  2024
# 3     9-2024      19.0       8.63               4.0  2024
# 4     8-2024      18.0       9.05               4.0  2024
# ..       ...       ...        ...               ...   ...
# 131   1-2014       5.5       6.07               NaN  2014
# 132  12-2013       5.5       6.47               NaN  2013
# 133  11-2013       5.5       6.50               NaN  2013
# 134  10-2013       5.5       6.27               NaN  2013
# 135   9-2013       5.5       6.14               NaN  2013
#
# [136 rows x 5 columns]

# %%
plt.figure(figsize=(30, 10))
plt.plot(df['Data'], df['Key_rate'], color= 'blue')
plt.plot(df['Data'], df['Inflation'], color= 'red')
plt.plot(df['Data'], df['Inflation_target'], color= 'green')
plt.title('Ключевая ставка Банка России и инфляция', size = 18)
plt.grid(True, linestyle='--', alpha=0.5)
plt.gca().invert_xaxis()
plt.xticks([])


indices = []
labels = []
for idx, date in enumerate(df["Year"]):
    if idx % 12 == 0:
        indices.append(idx)
        labels.append(date)

plt.xticks(indices, labels, size = 17)
plt.ylabel('Ключевая ставка (%)', size = 12)



plt.show()
